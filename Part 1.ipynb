# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Load Data

# %%
title_basics = 'https://datasets.imdbws.com/title.basics.tsv.gz'
title_akas = 'https://datasets.imdbws.com/title.akas.tsv.gz'
title_ratings = 'https://datasets.imdbws.com/title.ratings.tsv.gz'

# %%
basics = pd.read_csv(title_basics, sep='\t', low_memory=False)
akas = pd.read_csv(title_akas, sep='\t', low_memory=False)
ratings = pd.read_csv(title_ratings, sep='\t', low_memory=False)

# %% [markdown]
# # AKAs
#
# I will start the clean up process on the AKAs table first so that I can use it to filter other dataframes for the specification of keeping only US movies.

# %%
# Display the column names of akas
akas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36380969 entries, 0 to 36380968
# Data columns (total 8 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   titleId          object
#  1   ordering         int64
#  2   title            object
#  3   region           object
#  4   language         object
#  5   types            object
#  6   attributes       object
#  7   isOriginalTitle  object
# dtypes: int64(1), object(7)
# memory usage: 2.2+ GB

# %% [markdown]
# ### Replace "\N" with np.nan

# %%
# Replace "\N" with np.nan
akas.replace({'\\N':np.nan}, inplace=True)

# %% [markdown]
# ### Keep only US movies

# %%
# Display only US movies
filter_US = akas['region'] == 'US'
akas[filter_US]
# Out:
#             titleId  ordering                                      title  \
# 5         tt0000001         6                                 Carmencita
# 14        tt0000002         7                     The Clown and His Dogs
# 33        tt0000005        10                           Blacksmith Scene
# 36        tt0000005         1                        Blacksmithing Scene
# 41        tt0000005         6                        Blacksmith Scene #1
# ...             ...       ...                                        ...
# 36380495  tt9916560         1  March of Dimes Presents: Once Upon a Dime
# 36380565  tt9916620         1                          The Copeland Case
# 36380654  tt9916702         1              Loving London: The Playground
# 36380697  tt9916756         1                   Pretty Pretty Black Girl
# 36380713  tt9916764         1                                         38
#
#          region language        types             attributes isOriginalTitle
# 5            US      NaN  imdbDisplay                    NaN               0
# 14           US      NaN          NaN  literal English title               0
# 33           US      NaN  imdbDisplay                    NaN               0
# 36           US      NaN  alternative                    NaN               0
# 41           US      NaN  alternative                    NaN               0
# ...         ...      ...          ...                    ...             ...
# 36380495     US      NaN  imdbDisplay                    NaN               0
# 36380565     US      NaN  imdbDisplay                    NaN               0
# 36380654     US      NaN          NaN                    NaN               0
# 36380697     US      NaN  imdbDisplay                    NaN               0
# 36380713     US      NaN  imdbDisplay                    NaN               0
#
# [1447772 rows x 8 columns]

# %%
# Keep only US movies
akas = akas[filter_US]

# %% [markdown]
# ### Cleaned AKAs Dataframe

# %%
# Cleaned akas table per specification
akas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1447772 entries, 5 to 36380713
# Data columns (total 8 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   titleId          1447772 non-null  object
#  1   ordering         1447772 non-null  int64
#  2   title            1447772 non-null  object
#  3   region           1447772 non-null  object
#  4   language         3971 non-null     object
#  5   types            980613 non-null   object
#  6   attributes       46867 non-null    object
#  7   isOriginalTitle  1446430 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 99.4+ MB

# %% [markdown]
# # Basics

# %%
# Display the column names of basics
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9966186 entries, 0 to 9966185
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 684.3+ MB

# %% [markdown]
# ### Replace "\N" with np.nan

# %%
# Replace "\N" with np.nan
basics.replace({'\\N':np.nan}, inplace=True)

# %% [markdown]
# ### Eliminate movies that are null for runtimeMinutes

# %%
#Display the rows that contain null values in the runtimeMinutes column
filter1 = basics['runtimeMinutes'].isna() == True
basics[filter1]
# Out:
#             tconst  titleType                                   primaryTitle  \
# 18       tt0000019      short                               The Clown Barber
# 22       tt0000024      short                      Opening of the Kiel Canal
# 23       tt0000025      short  The Oxford and Cambridge University Boat Race
# 36       tt0000038      short                                  The Ball Game
# 37       tt0000039      short                              Barnet Horse Fair
# ...            ...        ...                                            ...
# 9966179  tt9916844  tvEpisode                                  Episode #3.15
# 9966180  tt9916846  tvEpisode                                  Episode #3.18
# 9966181  tt9916848  tvEpisode                                  Episode #3.17
# 9966182  tt9916850  tvEpisode                                  Episode #3.19
# 9966183  tt9916852  tvEpisode                                  Episode #3.20
#
#                                          originalTitle isAdult startYear  \
# 18                                    The Clown Barber       0      1898
# 22                           Opening of the Kiel Canal       0      1895
# 23       The Oxford and Cambridge University Boat Race       0      1896
# 36                                       The Ball Game       0      1898
# 37                                   Barnet Horse Fair       0      1896
# ...                                                ...     ...       ...
# 9966179                                  Episode #3.15       0      2009
# 9966180                                  Episode #3.18       0      2009
# 9966181                                  Episode #3.17       0      2009
# 9966182                                  Episode #3.19       0      2010
# 9966183                                  Episode #3.20       0      2010
#
#         endYear runtimeMinutes                   genres
# 18          NaN            NaN             Comedy,Short
# 22          NaN            NaN               News,Short
# 23          NaN            NaN         News,Short,Sport
# 36          NaN            NaN  Documentary,Short,Sport
# 37          NaN            NaN                    Short
# ...         ...            ...                      ...
# 9966179     NaN            NaN      Action,Drama,Family
# 9966180     NaN            NaN      Action,Drama,Family
# 9966181     NaN            NaN      Action,Drama,Family
# 9966182     NaN            NaN      Action,Drama,Family
# 9966183     NaN            NaN      Action,Drama,Family
#
# [7013666 rows x 9 columns]

# %%
# Eliminate movies that are null for runtimeMinutes
basics = basics[~filter1]

# %% [markdown]
# ### Eliminate movies that are null for genre

# %%
# Display the rows that contain null values in the genres column
filter2 = basics['genres'].isna() == True
basics[filter2]
# Out:
#             tconst titleType                primaryTitle  \
# 498      tt0000502     movie                    Bohemios
# 1616     tt0001630     movie            Der fremde Vogel
# 1739     tt0001756     movie       Lucha por la herencia
# 2069     tt0002094     movie                  Charles IV
# 2289     tt0002315     movie        El lobo de la sierra
# ...            ...       ...                         ...
# 9964805  tt9913834     movie       Hiniku: Nure nawazeme
# 9964826  tt9913878     movie  Document porno: Yubi ijime
# 9965400  tt9915130     movie               Meet John Doe
# 9965842  tt9916134     movie        The Thing in the Bag
# 9966126  tt9916730     movie                      6 Gunn
#
#                       originalTitle isAdult startYear endYear runtimeMinutes  \
# 498                        Bohemios       0      1905     NaN            100
# 1616               Der fremde Vogel       0      1911     NaN             45
# 1739          Lucha por la herencia       0      1911     NaN             92
# 2069                     Charles IV       0      1912     NaN             50
# 2289           El lobo de la sierra       0      1912     NaN             76
# ...                             ...     ...       ...     ...            ...
# 9964805       Hiniku: Nure nawazeme       0      1981     NaN             64
# 9964826  Document porno: Yubi ijime       0      1981     NaN             61
# 9965400               Meet John Doe       0       NaN     NaN            120
# 9965842        The Thing in the Bag       0       NaN     NaN             78
# 9966126                      6 Gunn       0      2017     NaN            116
#
#         genres
# 498        NaN
# 1616       NaN
# 1739       NaN
# 2069       NaN
# 2289       NaN
# ...        ...
# 9964805    NaN
# 9964826    NaN
# 9965400    NaN
# 9965842    NaN
# 9966126    NaN
#
# [76765 rows x 9 columns]

# %%
# Eliminate movies that are null for runtimeMinutes
basics = basics[~filter2]

# %% [markdown]
# ### Keep only titleType==Movie

# %%
# Display only titleType==Movie
filter3 = basics['titleType'] == 'Movie'
basics[filter3]
# Out:
# Empty DataFrame
# Columns: [tconst, titleType, primaryTitle, originalTitle, isAdult, startYear, endYear, runtimeMinutes, genres]
# Index: []

# %%
basics['titleType'].value_counts()
# Out:
# tvEpisode       1475884
# short            605646
# movie            384449
# video            181728
# tvMovie           92152
# tvSeries          91089
# tvSpecial         18401
# tvMiniSeries      17390
# tvShort            8692
# videoGame           324
# Name: titleType, dtype: int64

# %%
# Display only titleType==Movie
filter3 = basics['titleType'] == 'movie'
basics[filter3]
# Out:
#             tconst titleType  \
# 8        tt0000009     movie
# 144      tt0000147     movie
# 570      tt0000574     movie
# 587      tt0000591     movie
# 672      tt0000679     movie
# ...            ...       ...
# 9965952  tt9916362     movie
# 9966036  tt9916538     movie
# 9966077  tt9916622     movie
# 9966104  tt9916680     movie
# 9966136  tt9916754     movie
#
#                                               primaryTitle  \
# 8                                               Miss Jerry
# 144                          The Corbett-Fitzsimmons Fight
# 570                            The Story of the Kelly Gang
# 587                                       The Prodigal Son
# 672                         The Fairylogue and Radio-Plays
# ...                                                    ...
# 9965952                                              Coven
# 9966036                                Kuambil Lagi Hatiku
# 9966077        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9966104  De la ilusión al desconcierto: cine colombiano...
# 9966136                     Chico Albuquerque - Revelações
#
#                                              originalTitle isAdult startYear  \
# 8                                               Miss Jerry       0      1894
# 144                          The Corbett-Fitzsimmons Fight       0      1897
# 570                            The Story of the Kelly Gang       0      1906
# 587                                      L'enfant prodigue       0      1907
# 672                         The Fairylogue and Radio-Plays       0      1908
# ...                                                    ...     ...       ...
# 9965952                                           Akelarre       0      2020
# 9966036                                Kuambil Lagi Hatiku       0      2019
# 9966077        Rodolpho Teóphilo - O Legado de um Pioneiro       0      2015
# 9966104  De la ilusión al desconcierto: cine colombiano...       0      2007
# 9966136                     Chico Albuquerque - Revelações       0      2013
#
#         endYear runtimeMinutes                      genres
# 8           NaN             45                     Romance
# 144         NaN            100      Documentary,News,Sport
# 570         NaN             70  Action,Adventure,Biography
# 587         NaN             90                       Drama
# 672         NaN            120           Adventure,Fantasy
# ...         ...            ...                         ...
# 9965952     NaN             92               Drama,History
# 9966036     NaN            123                       Drama
# 9966077     NaN             57                 Documentary
# 9966104     NaN            100                 Documentary
# 9966136     NaN             49                 Documentary
#
# [384449 rows x 9 columns]

# %%
# Keep only titleType==Movie
basics = basics[filter3]

# %% [markdown]
# ###  Keep startYear 2000 - 2021

# %%
# Convert dtype of startYear column to float
basics['startYear'].astype(float)
# Out:
# 8          1894.0
# 144        1897.0
# 570        1906.0
# 587        1907.0
# 672        1908.0
#             ...
# 9965952    2020.0
# 9966036    2019.0
# 9966077    2015.0
# 9966104    2007.0
# 9966136    2013.0
# Name: startYear, Length: 384449, dtype: float64

# %%
# Filter for startYear 2000-2021
filter4 = basics['startYear'] >= '2000'
filter5 = basics['startYear'] <= '2021'
basics[filter4 & filter5]
# Out:
#             tconst titleType  \
# 13082    tt0013274     movie
# 34803    tt0035423     movie
# 42384    tt0043139     movie
# 61115    tt0062336     movie
# 67667    tt0069049     movie
# ...            ...       ...
# 9965952  tt9916362     movie
# 9966036  tt9916538     movie
# 9966077  tt9916622     movie
# 9966104  tt9916680     movie
# 9966136  tt9916754     movie
#
#                                               primaryTitle  \
# 13082                          Istoriya grazhdanskoy voyny
# 34803                                       Kate & Leopold
# 42384                          Life of a Beijing Policeman
# 61115    The Tango of the Widower and Its Distorting Mi...
# 67667                           The Other Side of the Wind
# ...                                                    ...
# 9965952                                              Coven
# 9966036                                Kuambil Lagi Hatiku
# 9966077        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9966104  De la ilusión al desconcierto: cine colombiano...
# 9966136                     Chico Albuquerque - Revelações
#
#                                              originalTitle isAdult startYear  \
# 13082                          Istoriya grazhdanskoy voyny       0      2021
# 34803                                       Kate & Leopold       0      2001
# 42384                                     Wo zhe yi bei zi       0      2013
# 61115            El tango del viudo y su espejo deformante       0      2020
# 67667                           The Other Side of the Wind       0      2018
# ...                                                    ...     ...       ...
# 9965952                                           Akelarre       0      2020
# 9966036                                Kuambil Lagi Hatiku       0      2019
# 9966077        Rodolpho Teóphilo - O Legado de um Pioneiro       0      2015
# 9966104  De la ilusión al desconcierto: cine colombiano...       0      2007
# 9966136                     Chico Albuquerque - Revelações       0      2013
#
#         endYear runtimeMinutes                  genres
# 13082       NaN             94             Documentary
# 34803       NaN            118  Comedy,Fantasy,Romance
# 42384       NaN            120           Drama,History
# 61115       NaN             70                   Drama
# 67667       NaN            122                   Drama
# ...         ...            ...                     ...
# 9965952     NaN             92           Drama,History
# 9966036     NaN            123                   Drama
# 9966077     NaN             57             Documentary
# 9966104     NaN            100             Documentary
# 9966136     NaN             49             Documentary
#
# [210919 rows x 9 columns]

# %%
# Keep only startYear 2000-2021
basics = basics[filter4 & filter5]

# %% [markdown]
# ### Eliminate movies that include "Documentary" in genre

# %%
# Display movies that are included in the documentary category.
is_documentary = basics['genres'].str.contains('documentary',case=False)
basics[is_documentary]
# Out:
#             tconst titleType  \
# 13082    tt0013274     movie
# 95148    tt0097304     movie
# 102653   tt0104988     movie
# 106709   tt0109173     movie
# 110936   tt0113506     movie
# ...            ...       ...
# 9965855  tt9916160     movie
# 9965866  tt9916186     movie
# 9966077  tt9916622     movie
# 9966104  tt9916680     movie
# 9966136  tt9916754     movie
#
#                                               primaryTitle  \
# 13082                          Istoriya grazhdanskoy voyny
# 95148                                 Everything's for You
# 102653                                  Neues in Wittstock
# 106709                                    Auf allen Meeren
# 110936                                Justifiable Homicide
# ...                                                    ...
# 9965855                                         Drømmeland
# 9965866  Illenau - die Geschichte einer ehemaligen Heil...
# 9966077        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9966104  De la ilusión al desconcierto: cine colombiano...
# 9966136                     Chico Albuquerque - Revelações
#
#                                              originalTitle isAdult startYear  \
# 13082                          Istoriya grazhdanskoy voyny       0      2021
# 95148                                 Everything's for You       0      2009
# 102653                                  Neues in Wittstock       0      2021
# 106709                                    Auf allen Meeren       0      2002
# 110936                                Justifiable Homicide       0      2002
# ...                                                    ...     ...       ...
# 9965855                                         Drømmeland       0      2019
# 9965866  Illenau - die Geschichte einer ehemaligen Heil...       0      2017
# 9966077        Rodolpho Teóphilo - O Legado de um Pioneiro       0      2015
# 9966104  De la ilusión al desconcierto: cine colombiano...       0      2007
# 9966136                     Chico Albuquerque - Revelações       0      2013
#
#         endYear runtimeMinutes       genres
# 13082       NaN             94  Documentary
# 95148       NaN             58  Documentary
# 102653      NaN            100  Documentary
# 106709      NaN             95  Documentary
# 110936      NaN             85  Documentary
# ...         ...            ...          ...
# 9965855     NaN             72  Documentary
# 9965866     NaN             84  Documentary
# 9966077     NaN             57  Documentary
# 9966104     NaN            100  Documentary
# 9966136     NaN             49  Documentary
#
# [72228 rows x 9 columns]

# %%
# Exclude movies that are included in the documentary category.
basics = basics[~is_documentary]

# %% [markdown]
# ### Keep only US movies using AKAs table

# %%
# Keep only US movies
# Filter the basics table down to only include the US by using the filter akas dataframe
keepers =basics['tconst'].isin(akas['titleId'])
basics = basics[keepers]

# %% [markdown]
# ### Cleaned Basics Dataframe

# %%
# Cleaned Basics table per specification
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 81799 entries, 34803 to 9965952
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          81799 non-null  object
#  1   titleType       81799 non-null  object
#  2   primaryTitle    81799 non-null  object
#  3   originalTitle   81799 non-null  object
#  4   isAdult         81799 non-null  object
#  5   startYear       81799 non-null  object
#  6   endYear         0 non-null      object
#  7   runtimeMinutes  81799 non-null  object
#  8   genres          81799 non-null  object
# dtypes: object(9)
# memory usage: 6.2+ MB

# %% [markdown]
# # Ratings

# %%
# Display the column names of akas
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1324473 entries, 0 to 1324472
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1324473 non-null  object
#  1   averageRating  1324473 non-null  float64
#  2   numVotes       1324473 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 30.3+ MB

# %% [markdown]
# ### Replace "\N" with np.nan

# %%
# Replace "\N" with np.nan
ratings.replace({'\\N':np.nan}, inplace=True)

# %% [markdown]
# ### Keep only US movies using AKAs table

# %%
# Keep only US movies
# Filter the ratings table down to only include the US by using the filter akas dataframe
keepers2 =ratings['tconst'].isin(akas['titleId'])
ratings = ratings[keepers2]

# %% [markdown]
# ### Cleaned Ratings Dataframe

# %%
# Cleaned Ratings table per specification
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 502224 entries, 0 to 1324448
# Data columns (total 3 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tconst         502224 non-null  object
#  1   averageRating  502224 non-null  float64
#  2   numVotes       502224 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 15.3+ MB

# %% [markdown]
# # Final .info() of each dataframe

# %%
print('Basics', '\n')
print(basics.info())
print('\n','AKAs', '\n')
print(akas.info())
print('\n','Ratings', '\n')
print(ratings.info())
# Out:
# Basics
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 81799 entries, 34803 to 9965952
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          81799 non-null  object
#  1   titleType       81799 non-null  object
#  2   primaryTitle    81799 non-null  object
#  3   originalTitle   81799 non-null  object
#  4   isAdult         81799 non-null  object
#  5   startYear       81799 non-null  object
#  6   endYear         0 non-null      object
#  7   runtimeMinutes  81799 non-null  object
#  8   genres          81799 non-null  object
# dtypes: object(9)
# memory usage: 6.2+ MB
# None
#
#  AKAs
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1447772 entries, 5 to 36380713
# Data columns (total 8 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   titleId          1447772 non-null  object
#  1   ordering         1447772 non-null  int64
#  2   title            1447772 non-null  object
#  3   region           1447772 non-null  object
#  4   language         3971 non-null     object
#  5   types            980613 non-null   object
#  6   attributes       46867 non-null    object
#  7   isOriginalTitle  1446430 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 99.4+ MB
# None
#
#  Ratings
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 502224 entries, 0 to 1324448
# Data columns (total 3 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tconst         502224 non-null  object
#  1   averageRating  502224 non-null  float64
#  2   numVotes       502224 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 15.3+ MB
# None

# %% [markdown]
# # Create a "Data" folder

# %%
import os
os.makedirs('Data/',exist_ok=True) 
# Confirm folder created
os.listdir("Data/")
# Out:
# ['title_basics.csv.gz', 'title_akas.csv.gz', 'title_ratings.csv.gz']

# %% [markdown]
# # Save each file to a compressed csv file "Data/" folder inside your repository.

# %%
## Save current dataframe to file.
basics.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)

# %%
akas.to_csv("Data/title_akas.csv.gz",compression='gzip',index=False)

# %%
ratings.to_csv("Data/title_ratings.csv.gz",compression='gzip',index=False)

# %% [markdown]
# # Check the saved csv file

# %%
# Open saved file and preview again
basics = pd.read_csv("Data/title_basics.csv.gz", low_memory = False)
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0043139     movie                        Life of a Beijing Policeman
# 2  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 3  tt0069049     movie                         The Other Side of the Wind
# 4  tt0088751     movie                                  The Naked Monster
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1                           Wo zhe yi bei zi        0       2013      NaN
# 2  El tango del viudo y su espejo deformante        0       2020      NaN
# 3                 The Other Side of the Wind        0       2018      NaN
# 4                          The Naked Monster        0       2005      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1             120           Drama,History
# 2              70                   Drama
# 3             122                   Drama
# 4             100    Comedy,Horror,Sci-Fi

# %%
# Open saved file and preview again
akas = pd.read_csv("Data/title_akas.csv.gz", low_memory = False)
akas.head()
# Out:
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 2  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#               attributes  isOriginalTitle
# 0                    NaN              0.0
# 1  literal English title              0.0
# 2                    NaN              0.0
# 3                    NaN              0.0
# 4                    NaN              0.0

# %%
# Open saved file and preview again
ratings = pd.read_csv("Data/title_ratings.csv.gz", low_memory = False)
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1982
# 1  tt0000002            5.8       265
# 2  tt0000005            6.2      2625
# 3  tt0000006            5.1       182
# 4  tt0000007            5.4       820
